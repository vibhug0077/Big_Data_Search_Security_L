# %% [markdown]
# ## Execution context
#
# Theory content: available in the private theory repository
# Public code root: `C:\UPES\Repos\Big_Data_Search_Security_L`
# Container root: `/workspace`
#
# This source notebook is a historical Elasticsearch client snapshot. Use the public workbook's supplied `products.json` and smoke-test command for the current reproducible path.
#
# **Execution status:** platform-dependent. The client cells require an Elasticsearch service at `http://localhost:9200/` and the `elasticsearch` Python package. The service-backed cells intentionally have no fabricated output here; use the recorded output in the public workbook after running the smoke test.

# %%
# !pip install elasticsearch

# %%
from elasticsearch import Elasticsearch

# %%
es = Elasticsearch("http://localhost:9200/", request_timeout=60)

# %%
es
# Out:
# <Elasticsearch(['http://localhost:9200'])>

# %%
# Index a simple document
document = {
    "name" : "John Smith",
    "age" : 40,
    "department" : "IT",
    "occupation" : "Software Engineer",
    "branch" : "Noida"
}

es.index(index="emp", id=1, document=document)
# Out:
# ObjectApiResponse({'_index': 'emp', '_id': '1', '_version': 2, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1, '_primary_term': 1})

# %%
query = {
    "query" : {
        "match" : {
            "branch" : "Noida"
        }
    }
}

response = es.search(index="emp", body=query)

# %%
print("Search Results :", response)
# Out:
# Search Results : {'took': 58, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 1, 'relation': 'eq'}, 'max_score': 0.18232156, 'hits': [{'_index': 'emp', '_id': '1', '_score': 0.18232156, '_source': {'name': 'John Smith', 'age': 40, 'department': 'IT', 'occupation': 'Software Engineer', 'branch': 'Noida'}}]}}

# %%
response["hits"]["hits"]
# Out:
# [{'_index': 'emp',
#   '_id': '1',
#   '_score': 0.18232156,
#   '_source': {'name': 'John Smith',
#    'age': 40,
#    'department': 'IT',
#    'occupation': 'Software Engineer',
#    'branch': 'Noida'}}]
